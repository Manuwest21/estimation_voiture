# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import seaborn as sns
from sklearn.model_selection import train_test_split
from ydata_profiling import ProfileReport
import numpy as np

# %%
a=np.array([1,2,3])
# a.ndim
# a.shape
# a.size
# b=np.zeros((3,3))
# b
a

np.random.randn(8,9)
np.random.sample(3)
np.linspace(12,24,17, dtype=np.float16)
# Out:
# array([12.  , 12.75, 13.5 , 14.25, 15.  , 15.75, 16.5 , 17.25, 18.  ,
#        18.75, 19.5 , 20.25, 21.  , 21.75, 22.5 , 23.25, 24.  ],
#       dtype=float16)

# %%
np.arange(0,17,3)
# Out:
# array([ 0,  3,  6,  9, 12, 15])

# %%
# y = df['quality']# ou df.drop("price", axis=1) pr dire qu'on suppr 1 colonne)
# X = df[["alcohol",'sulphates','acid_fix']]
# X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
# model = LinearRegression()
# trained_model = model.fit(X_train,y_train)
# trained_model.score(X_test,y_test)
# model.predict(X)

# %%
# model.predict(X)

# %%
df= pd.read_csv("voiture.csv")

# %%
# model = Ridge()
# trained_model = model.fit(X_train,y_train)
# trained_model.score(X_test,y_test)

# %%
df=pd.read_csv("voiture.csv")
df = df.rename(columns={'symboling': 'etat_de_route', 'CarName': 'marque_voiture', 'fueltype': 'carburant', 'aspiration': 'turbo', 'doornumber': 'nombre_portes', 'carbody': 'type_vehicule', 'drivewheel': 'roues_motrices', 'enginelocation': 'emplacement_moteur', 'wheelbase': 'empattement', 'carlength': 'longueur_voiture', 'carwidth': 'largeur_voiture', 'carheight': 'hauteur_voiture', 'curbweight': 'poids_vehicule', 'enginetype': 'type_moteur', 'cylindernumber': 'nombre_cylindres', 'enginesize': 'taille_moteur', 'fuelsystem': 'systeme_carburant', 'boreratio': 'taux_alésage', 'stroke': 'course', 'compressionratio': 'taux_compression', 'horsepower': 'chevaux', 'peakrpm': 'tour_moteur', 'citympg': 'consommation_ville', 'highwaympg': 'consommation_autoroute', 'price': 'prix'})

# %%
df.describe()
# Out:
#            car_ID  etat_de_route  empattement  longueur_voiture  \
# count  205.000000     205.000000   205.000000        205.000000
# mean   103.000000       0.834146    98.756585        174.049268
# std     59.322565       1.245307     6.021776         12.337289
# min      1.000000      -2.000000    86.600000        141.100000
# 25%     52.000000       0.000000    94.500000        166.300000
# 50%    103.000000       1.000000    97.000000        173.200000
# 75%    154.000000       2.000000   102.400000        183.100000
# max    205.000000       3.000000   120.900000        208.100000
#
#        largeur_voiture  hauteur_voiture  poids_vehicule  taille_moteur  \
# count       205.000000       205.000000      205.000000     205.000000
# mean         65.907805        53.724878     2555.565854     126.907317
# std           2.145204         2.443522      520.680204      41.642693
# min          60.300000        47.800000     1488.000000      61.000000
# ...

# %% [markdown]
# # colonne 16  remplacer nbre cylindres

# %%
valeurs_uniques = df['nombre_cylindres'].unique()
valeurs_uniques

# %%
df["nombre_cylindres"].replace({"two": 2, "three":3, "four":4, "five":5, "six":6, "eight":8, "twelve":12}, inplace=True)

# %%
valeurs_uniques = df['nombre_cylindres'].unique()
valeurs_uniques
# Out:
# array([ 4,  6,  5,  3, 12,  2,  8])

# %% [markdown]
# # 17 convertir métrique

# %%
alpha giulia :2143

* par 16.387 pour avoir taille_moteur us en cc3

# %%
df.loc[:, 'taille_moteur'] = round(df.loc[:, 'taille_moteur'] * 16.387)
df
# Out:
# /tmp/ipykernel_14554/3175912708.py:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, 'taille_moteur'] = round(df.loc[:, 'taille_moteur'] * 16.387)
#      car_ID  etat_de_route            marque_voiture carburant  turbo  \
# 0         1              3        alfa-romero giulia       gas    std
# 1         2              3       alfa-romero stelvio       gas    std
# 2         3              1  alfa-romero Quadrifoglio       gas    std
# 3         4              2               audi 100 ls       gas    std
# 4         5              2                audi 100ls       gas    std
# ..      ...            ...                       ...       ...    ...
# 200     201             -1           volvo 145e (sw)       gas    std
# ...

# %%
df = df.rename(columns={'taille_moteur': 'moteur_cc3'})

# %%
valeurs_uniques = df['colonne1'].unique()
print(valeurs_uniques)

# %% [markdown]
# # 18 systeme carburant

# %%
valeurs_uniques = df['systeme_carburant'].unique()
print(valeurs_uniques)
# Out:
# ['mpfi' '2bbl' 'mfi' '1bbl' 'spfi' '4bbl' 'idi' 'spdi']

# %%
df["nombre_cylindres"].replace({"mpfi": "injection multipoint", "'2bbl": "carburateur 2 corps", "mfi":///, "1bbl":"carburateur 1 corps", "spfi": "injection monopoint", "4bbl":"carburateur 4 corps", "idi":"injection indirecte", "spdi":"injection D monopoint"}, inplace=True)

# %%
df["nombre_cylindres"].replace({"mpfi": "injection multipoint", "'2bbl": "carburateur 2 corps", "mfi":///, "1bbl":"C1C", "spfi": "IMP", "4bbl":"C4C", "idi":"IID", "spdi":"IDMP"}, inplace=True)

# %% [markdown]
# # 19 taux alesage en cc3

# %%
 df.loc[:, 'taux_alésage'] = round(df.loc[:, 'taux_alésage'] * )

# %%
profile=ProfileReport(df, title="vignerons")
profile.to_file('ici.html')

# %%
profile.to_file('ici.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df['consommation_ville'] = 235.214583/df['consommation_ville']
df['consommation_autoroute'] = 235.214583/df['consommation_autoroute']

# %%
df.head(35)
# Out:
#     car_ID  etat_de_route             marque_voiture carburant  turbo  \
# 0        1              3         alfa-romero giulia       gas    std
# 1        2              3        alfa-romero stelvio       gas    std
# 2        3              1   alfa-romero Quadrifoglio       gas    std
# 3        4              2                audi 100 ls       gas    std
# 4        5              2                 audi 100ls       gas    std
# 5        6              2                   audi fox       gas    std
# 6        7              1                 audi 100ls       gas    std
# 7        8              1                  audi 5000       gas    std
# 8        9              1                  audi 4000       gas  turbo
# 9       10              0        audi 5000s (diesel)       gas  turbo
# 10      11              2                   bmw 320i       gas    std
# 11      12              0                   bmw 320i       gas    std
# ...

# %%
df.columns
# Out:
# Index(['car_ID', 'etat_de_route', 'marque_voiture', 'carburant', 'turbo',
#        'nombre_portes', 'type_vehicule', 'roues_motrices',
#        'emplacement_moteur', 'empattement', 'longueur_voiture',
#        'largeur_voiture', 'hauteur_voiture', 'poids_vehicule', 'type_moteur',
#        'nombre_cylindres', 'taille_moteur', 'systeme_carburant',
#        'taux_alésage', 'course', 'taux_compression', 'chevaux', 'tour_moteur',
#        'consommation_ville', 'consommation_autoroute', 'prix'],
#       dtype='object')

# %%
valeurs_uniques = df['marque_voiture'].unique()
print(valeurs_uniques)
# Out:
# ['alfa-romero giulia' 'alfa-romero stelvio' 'alfa-romero Quadrifoglio'
#  'audi 100 ls' 'audi 100ls' 'audi fox' 'audi 5000' 'audi 4000'
#  'audi 5000s (diesel)' 'bmw 320i' 'bmw x1' 'bmw x3' 'bmw z4' 'bmw x4'
#  'bmw x5' 'chevrolet impala' 'chevrolet monte carlo' 'chevrolet vega 2300'
#  'dodge rampage' 'dodge challenger se' 'dodge d200' 'dodge monaco (sw)'
#  'dodge colt hardtop' 'dodge colt (sw)' 'dodge coronet custom'
#  'dodge dart custom' 'dodge coronet custom (sw)' 'honda civic'
#  'honda civic cvcc' 'honda accord cvcc' 'honda accord lx'
#  'honda civic 1500 gl' 'honda accord' 'honda civic 1300' 'honda prelude'
#  'honda civic (auto)' 'isuzu MU-X' 'isuzu D-Max ' 'isuzu D-Max V-Cross'
#  'jaguar xj' 'jaguar xf' 'jaguar xk' 'maxda rx3' 'maxda glc deluxe'
#  'mazda rx2 coupe' 'mazda rx-4' 'mazda glc deluxe' 'mazda 626' 'mazda glc'
#  'mazda rx-7 gs' 'mazda glc 4' 'mazda glc custom l' 'mazda glc custom'
#  'buick electra 225 custom' 'buick century luxus (sw)' 'buick century'
# ...

# %%
#df["marque_voiture"].replace({"audi 100ls": "audi 100 ls"}, inplace=True)

# %%
import pandas_profiling
profile = pandas_profiling.ProfileReport(df, title="vignerons")
profile.to_widgets()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 import pandas_profiling
#       2 profile = pandas_profiling.ProfileReport(df, title="vignerons")
#       3 profile.to_widgets()
#
# File ~/miniconda3/envs/sklearn-env/lib/python3.11/site-packages/pandas_profiling/__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File ~/miniconda3/envs/sklearn-env/lib/python3.11/site-packages/pandas_profiling/controller/pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ...

# %%
df.info()

# %%
df= df.rename(columns={'fixed acidity':'acid_fix'}).rename(columns={'volatile acidity':'acid_vol'}).rename(columns={'citric acid':'acid_cit'}).rename(columns={'residual sugar':'sugar'}).rename(columns={'free sulfur dioxide':'dioxide_free'}).rename(columns={'total sulfur dioxide':'dioxide_total'})

# %%
df["alcohol",'sulphates','acid_fix']

# %%
df.corr()

# %%
valeurs_uniques = df['colonne1'].unique()
print(valeurs_uniques)
